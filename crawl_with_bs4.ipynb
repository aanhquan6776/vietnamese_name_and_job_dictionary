# %%
import requests
from bs4 import BeautifulSoup

# %%
root = "https://thongtinthuebao.com"
def saveData(url, records):
    datafile = "crawled/" + url.replace('/', '_') + ".txt"
    with open(datafile, "w") as file:
        output = "\n".join(records)
        file.write(output)

        
def checkHistory(url):
    """
    return True if the url is already exist
    """
    logfile = "crawled/history.txt"
    with open(logfile, "r") as records:
        return ((url+"\n") in records)
    
def updateHistory(url):
    logfile = "crawled/history.txt"
    with open(logfile, "a") as file:
        file.write(url+"\n")
        

def getNextPage(full_url):
    # Collect and parse first page
    page = requests.get(full_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    pagination = soup.find(class_="pagination")
    
    if pagination:
        next_urls = pagination.find_all('a', href=True)

        current_reached = False
        for next_url in next_urls:
            if current_reached:
                return root + next_url['href']
#             print(next_url.contents[0])
            if (next_url['href'].strip() == "javascript:") and (next_url.contents[0].strip()!='500'):
                current_reached = True
    return ""


def getData(full_url):
    result = []
    # Collect and parse first page
    page = requests.get(full_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    blocks = soup.find_all(class_='text-uppercase push-10')

    for block in blocks:
        record = block.find('a')
        info = record.contents[0]
        result.append(info)
        
    return result


def getAllData(url):
    result = []
    if checkHistory(url):
        return result
    tmp_url = root + url
    while True:
        print(tmp_url)
        result.extend(getData(tmp_url))
        tmp_url = getNextPage(tmp_url)
        if len(tmp_url)==0:
            break
        
    saveData(url, result)
    updateHistory(url)
    print(url, ': ', len(result))
    return result
    
    
def isElemental(url):
    if url=="":
        return False
    
    # Collect and parse first page
    full_url = root + url
    page = requests.get(full_url)
    soup = BeautifulSoup(page.text, 'html.parser')
    
    right_column = soup.find_all(class_="block-content block-content-full")
    return len(right_column)==1
    
    
def getSubURLs(full_url):
    result = []
    # Collect and parse first page
    page = requests.get(full_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    sub_urls_part = soup.find(class_="block-content block-content-full")

    if sub_urls_part:
        records = sub_urls_part.find_all('a', href=True)

    for record in records:
        sub_url = record['href']
        result.append(sub_url)
        
    return result


def dfs(url):
    print(url)
    if isElemental(url):
        return getAllData(url)
    
    result = []
    if checkHistory(url):
        return result
    full_url = root + url
    sub_urls = getSubURLs(full_url)
    for sub_url in sub_urls:
        result.extend(dfs(sub_url))
        
    return result

# %%
records = dfs("")
# Out:
# /ha-noi
# /ha-noi/huyen-dong-anh
# /ha-noi/huyen-dong-anh/thi-tran-dong-anh
# /ha-noi/huyen-dong-anh/xa-uy-no
# /ha-noi/huyen-dong-anh/xa-lien-ha
# /ha-noi/huyen-dong-anh/xa-co-loa
# /ha-noi/huyen-dong-anh/xa-duc-tu
# /ha-noi/huyen-dong-anh/xa-hai-boi
# /ha-noi/huyen-dong-anh/xa-kim-no
# /ha-noi/huyen-dong-anh/xa-viet-hung
# /ha-noi/huyen-dong-anh/xa-vinh-ngoc
# /ha-noi/huyen-dong-anh/xa-tien-duong
# /ha-noi/huyen-dong-anh/xa-mai-lam
# /ha-noi/thi-xa-son-tay/xa-thanh-my
# /ha-noi/thi-xa-son-tay/phuong-phu-thinh
# /ha-noi/thi-xa-son-tay/phuong-trung-son-tram
# /ha-noi/thi-xa-son-tay/phuong-vien-son
# /ha-noi/thi-xa-son-tay/phuong-trung-hung
# /ha-noi/thi-xa-son-tay/xa-kim-son
# /ha-noi/thi-xa-son-tay/xa-duong-lam
# /ha-noi/thi-xa-son-tay/xa-son-dong
# /ha-noi/thi-xa-son-tay/xa-co-dong
# /ha-noi/thi-xa-son-tay/phuong-le-loi
# /ha-noi/thi-xa-son-tay/xa-xuan-son
# /ha-noi/thi-xa-son-tay/phuong-ngo-quyen
# /ha-noi/huyen-thuong-tin
# /ha-noi/huyen-thuong-tin/thi-tran-thuong-tin
# /ha-noi/huyen-thuong-tin/xa-to-hieu
# /ha-noi/huyen-thuong-tin/xa-minh-cuong
# /ha-noi/huyen-thuong-tin/xa-ha-hoi
# /ha-noi/huyen-thuong-tin/xa-van-binh
# /ha-noi/huyen-thuong-tin/xa-hoa-binh
# /ha-noi/huyen-thuong-tin/xa-nhi-khe
# /ha-noi/huyen-thuong-tin/xa-van-diem
# /ha-noi/huyen-thuong-tin/xa-duyen-thai
# /ha-noi/huyen-thuong-tin/xa-thang-loi
# /ha-noi/huyen-thuong-tin/xa-tien-phong
# /ha-noi/huyen-thuong-tin/xa-le-loi
# /ha-noi/huyen-thuong-tin/xa-van-tu
# /ha-noi/huyen-thuong-tin/xa-van-tao
# /ha-noi/huyen-thuong-tin/xa-dung-tien
# /ha-noi/huyen-thuong-tin/xa-lien-phuong
# /ha-noi/huyen-thuong-tin/xa-hong-van
# /ha-noi/huyen-thuong-tin/xa-quat-dong
# /ha-noi/huyen-thuong-tin/xa-nghiem-xuyen
# /ha-noi/huyen-thuong-tin/xa-tu-nhien
# /ha-noi/huyen-thuong-tin/xa-thong-nhat
# /ha-noi/huyen-thuong-tin/xa-hien-giang
# /ha-noi/huyen-thuong-tin/xa-tan-minh
# /ha-noi/huyen-thuong-tin/xa-van-phu
# /ha-noi/huyen-thuong-tin/xa-nguyen-trai
# /ha-noi/huyen-thuong-tin/xa-khanh-ha
# /ha-noi/huyen-thuong-tin/xa-ninh-so
# /ha-noi/huyen-thuong-tin/xa-thu-phu
# /ha-noi/huyen-thuong-tin/xa-chuong-duong
# /ha-noi/huyen-chuong-my
# /ha-noi/huyen-chuong-my/thi-tran-xuan-mai
# /ha-noi/huyen-chuong-my/xa-thuy-xuan-tien
# /ha-noi/huyen-chuong-my/thi-tran-chuc-son
# /ha-noi/huyen-chuong-my/xa-phung-chau
# /ha-noi/huyen-chuong-my/xa-dong-son
# /ha-noi/huyen-chuong-my/xa-tien-phuong
# /ha-noi/huyen-chuong-my/xa-dong-phuong-yen
# /ha-noi/huyen-chuong-my/xa-truong-yen
# /ha-noi/huyen-chuong-my/xa-thanh-binh
# /ha-noi/huyen-chuong-my/xa-nam-phuong-tien
# /ha-noi/huyen-chuong-my/xa-phu-nghia
# /ha-noi/huyen-chuong-my/xa-tran-phu
# /ha-noi/huyen-chuong-my/xa-hoang-van-thu
# /ha-noi/huyen-chuong-my/xa-ngoc-hoa
# /ha-noi/huyen-chuong-my/xa-hoa-chinh
# /ha-noi/huyen-chuong-my/xa-hop-dong
# /ha-noi/huyen-chuong-my/xa-tan-tien
# /ha-noi/huyen-chuong-my/xa-trung-hoa
# /ha-noi/huyen-chuong-my/xa-quang-bi
# /ha-noi/huyen-chuong-my/xa-hoang-dieu
# /ha-noi/huyen-chuong-my/xa-my-luong
# /ha-noi/huyen-chuong-my/xa-thuy-huong
# /ha-noi/huyen-chuong-my/xa-huu-van
# /ha-noi/huyen-chuong-my/xa-dai-yen
# /ha-noi/huyen-chuong-my/xa-lam-dien
# /ha-noi/huyen-chuong-my/xa-dong-phu
# /ha-noi/huyen-chuong-my/xa-tot-dong
# /ha-noi/huyen-chuong-my/xa-hong-phong
# /ha-noi/huyen-chuong-my/xa-phu-nam-an
# /ha-noi/huyen-chuong-my/xa-dong-lac
# /ha-noi/huyen-chuong-my/xa-thuong-vuc
# /ha-noi/huyen-chuong-my/xa-van-vo
# /ha-noi/huyen-me-linh
# /ha-noi/huyen-me-linh/thi-tran-quang-minh
# /ha-noi/huyen-me-linh/xa-me-linh
# /ha-noi/huyen-me-linh/xa-thanh-lam
# /ha-noi/huyen-me-linh/xa-tien-phong
# /ha-noi/huyen-me-linh/xa-thach-da
# /ha-noi/huyen-me-linh/xa-dai-thinh
# /ha-noi/huyen-me-linh/xa-kim-hoa
# /ha-noi/huyen-me-linh/xa-van-khe
# /ha-noi/huyen-me-linh/xa-trang-viet
# /ha-noi/huyen-me-linh/xa-tien-thinh
# /ha-noi/huyen-me-linh/xa-lien-mac
# /ha-noi/huyen-me-linh/xa-tu-lap
# /ha-noi/huyen-me-linh/xa-tien-thang
# /ha-noi/huyen-me-linh/xa-tam-dong
# /ha-noi/huyen-me-linh/xa-chu-phan
# /ha-noi/huyen-me-linh/xa-van-yen
# /ha-noi/huyen-me-linh/xa-hoang-kim
# /ha-noi/huyen-thach-that
# /ha-noi/huyen-thach-that/xa-huu-bang
# /ha-noi/huyen-thach-that/xa-chang-son
# /ha-noi/huyen-thach-that/xa-phung-xa
# /ha-noi/huyen-thach-that/xa-canh-nau
# /ha-noi/huyen-thach-that/xa-binh-yen
# /ha-noi/huyen-thach-that/xa-binh-phu
# /ha-noi/huyen-thach-that/xa-di-nau
# /ha-noi/huyen-thach-that/thi-tran-lien-quan
# /ha-noi/huyen-thach-that/xa-huong-ngai
# /ha-noi/huyen-thach-that/xa-thach-xa
# /ha-noi/huyen-thach-that/xa-dai-dong
# /ha-noi/huyen-thach-that/xa-phu-kim
# /ha-noi/huyen-thach-that/xa-kim-quan
# /ha-noi/huyen-thach-that/xa-ha-bang
# /ha-noi/huyen-thach-that/xa-lai-thuong
# /ha-noi/huyen-thach-that/xa-can-kiem
# /ha-noi/huyen-my-duc/xa-phu-luu-te
# /ha-noi/huyen-my-duc/xa-hop-tien
# /ha-noi/huyen-my-duc/xa-dai-hung
# /ha-noi/huyen-my-duc/xa-le-thanh
# /ha-noi/huyen-my-duc/xa-phung-xa
# /ha-noi/huyen-my-duc/xa-phuc-lam
# /ha-noi/huyen-my-duc/xa-an-my
# /ha-noi/huyen-my-duc/xa-bot-xuyen
# /ha-noi/huyen-my-duc/xa-xuy-xa
# /ha-noi/huyen-my-duc/xa-hong-son
# /ha-noi/huyen-my-duc/xa-my-thanh
# /ha-noi/huyen-my-duc/xa-tuy-lai
# /ha-noi/huyen-my-duc/xa-an-tien
# /ha-noi/huyen-my-duc/xa-van-kim
# /ha-noi/huyen-my-duc/xa-dong-tam
# /ha-noi/huyen-my-duc/xa-hung-tien
# /ha-noi/huyen-my-duc/xa-thuong-lam
# /ha-noi/huyen-my-duc/xa-doc-tin
# /ha-noi/huyen-my-duc/xa-an-phu
# /ha-noi/huyen-quoc-oai
# /ha-noi/huyen-quoc-oai/thi-tran-quoc-oai
# /ha-noi/huyen-quoc-oai/xa-hoa-thach
# /ha-noi/huyen-quoc-oai/xa-thach-than
# /ha-noi/huyen-quoc-oai/xa-sai-son
# /ha-noi/huyen-quoc-oai/xa-ngoc-my
# /ha-noi/huyen-quoc-oai/xa-phu-cat
# /ha-noi/huyen-quoc-oai/xa-nghia-huong
# /ha-noi/huyen-quoc-oai/xa-dong-quang
# /ha-noi/huyen-quoc-oai/xa-yen-son
# /ha-noi/huyen-quoc-oai/xa-can-huu
# /ha-noi/huyen-quoc-oai/xa-tan-hoa
# /ha-noi/huyen-quoc-oai/xa-phuong-cach
# /ha-noi/huyen-quoc-oai/xa-liep-tuyet
# /ha-noi/huyen-quoc-oai/xa-tuyet-nghia
# /ha-noi/huyen-quoc-oai/xa-phu-man
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cc91dc0f7b93> in <module>
# ----> 1 records = dfs("")
#
# <ipython-input-2-c8de743a912a> in dfs(url)
#     115     sub_urls = getSubURLs(full_url)
#     116     for sub_url in sub_urls:
# --> 117         result.extend(dfs(sub_url))
#     118
#     119     return result
#
# <ipython-input-2-c8de743a912a> in dfs(url)
#     115     sub_urls = getSubURLs(full_url)
#     116     for sub_url in sub_urls:
# --> 117         result.extend(dfs(sub_url))
#     118
#     119     return result
#
# <ipython-input-2-c8de743a912a> in dfs(url)
#     115     sub_urls = getSubURLs(full_url)
#     116     for sub_url in sub_urls:
# --> 117         result.extend(dfs(sub_url))
#     118
#     119     return result
#
# <ipython-input-2-c8de743a912a> in dfs(url)
#     107
#     108 def dfs(url):
# --> 109     print(url)
#     110     if isElemental(url):
#     111         return getAllData(url)
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     398                 string = string.decode(self.encoding, 'replace')
#     399
# --> 400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
#     402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/iostream.py in _is_master_process(self)
#     308
#     309     def _is_master_process(self):
# --> 310         return os.getpid() == self._master_pid
#     311
#     312     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %%
print(len(records))
print(records)
